# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# File to Load (Remember to change these)
video_games_to_load = "Data/video_games.csv"

# Read the all games and video games Data
video_games_df = pd.read_csv(video_games_to_load)

# %%
video_games_df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
# 5  Nintendo     23.20      2.26      4.22         0.58         30.26
# 6  Nintendo     11.28      9.14      6.50         2.88         29.80
# 7  Nintendo     13.96      9.18      2.93         2.84         28.92
# 8  Nintendo     14.44      6.94      4.70         2.24         28.32
# 9  Nintendo     26.93      0.63      0.28         0.47         28.31
#
#    Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0          76.0          51.0          8       322.0  Nintendo      E
# 1           NaN           NaN        NaN         NaN       NaN    NaN
# 2          82.0          73.0        8.3       709.0  Nintendo      E
# 3          80.0          73.0          8       192.0  Nintendo      E
# 4           NaN           NaN        NaN         NaN       NaN    NaN
# 5           NaN           NaN        NaN         NaN       NaN    NaN
# 6          89.0          65.0        8.5       431.0  Nintendo      E
# 7          58.0          41.0        6.6       129.0  Nintendo      E
# 8          87.0          80.0        8.4       594.0  Nintendo      E
# 9           NaN           NaN        NaN         NaN       NaN    NaN

# %%
video_games_df.shape
# Out:
# (16719, 16)

# %%
video_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
# Rename Name to name column in video_games_df
video_games_df.columns = video_games_df.columns.str.lower()
video_games_df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           publisher  na_sales  eu_sales  jp_sales  other_sales  global_sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        critic_score  critic_count user_score  user_count developer rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
# renaming platform types abrv in video_games_df to match all_games_df platform names using the mapping method
mapping = {'N64':'Nintendo 64','PS':'PlayStation','PS3': 'PlayStation 3','DC':'Dreamcast','X360':'Xbox 360','XOne':'Xbox One',
          'Wii':'Wii','PC':'PC','PS2':'PlayStation 2','PS4':'PlayStation 4','GC':'GameCube','XB':'Xbox','WiiU':'Wii U',
          'GBA':'Game Boy Advance','3DS':'3DS','2600':'Atari','DS':'DS','PSV':'PlayStation Vita','PSP':'PSP','GB':'Game Boy',
           'NES':'Nintendo','PSP':'PlayStation Portable'}
video_games_df['platform'] = video_games_df['platform'].map(mapping)
video_games_df
# Out:
#                                 name          platform  year_of_release  \
# 0                         Wii Sports               Wii           2006.0
# 1                  Super Mario Bros.          Nintendo           1985.0
# 2                     Mario Kart Wii               Wii           2008.0
# 3                  Wii Sports Resort               Wii           2009.0
# 4           Pokemon Red/Pokemon Blue          Game Boy           1996.0
# ...                              ...               ...              ...
# 16714  Samurai Warriors: Sanada Maru     PlayStation 3           2016.0
# 16715               LMA Manager 2007          Xbox 360           2006.0
# 16716        Haitaka no Psychedelica  PlayStation Vita           2016.0
# 16717               Spirits & Spells  Game Boy Advance           2003.0
# 16718            Winning Post 8 2016  PlayStation Vita           2016.0
#
#               genre     publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports      Nintendo     41.36     28.96      3.77         8.45
# 1          Platform      Nintendo     29.08      3.58      6.81         0.77
# 2            Racing      Nintendo     15.68     12.76      3.79         3.29
# 3            Sports      Nintendo     15.61     10.93      3.28         2.95
# 4      Role-Playing      Nintendo     11.27      8.89     10.22         1.00
# ...             ...           ...       ...       ...       ...          ...
# 16714        Action    Tecmo Koei      0.00      0.00      0.01         0.00
# 16715        Sports   Codemasters      0.00      0.01      0.00         0.00
# 16716     Adventure  Idea Factory      0.00      0.00      0.01         0.00
# 16717      Platform       Wanadoo      0.01      0.00      0.00         0.00
# 16718    Simulation    Tecmo Koei      0.00      0.00      0.01         0.00
#
#        global_sales  critic_score  critic_count user_score  user_count  \
# 0             82.53          76.0          51.0          8       322.0
# 1             40.24           NaN           NaN        NaN         NaN
# 2             35.52          82.0          73.0        8.3       709.0
# 3             32.77          80.0          73.0          8       192.0
# 4             31.37           NaN           NaN        NaN         NaN
# ...             ...           ...           ...        ...         ...
# 16714          0.01           NaN           NaN        NaN         NaN
# 16715          0.01           NaN           NaN        NaN         NaN
# 16716          0.01           NaN           NaN        NaN         NaN
# 16717          0.01           NaN           NaN        NaN         NaN
# 16718          0.01           NaN           NaN        NaN         NaN
#
#       developer rating
# 0      Nintendo      E
# 1           NaN    NaN
# 2      Nintendo      E
# 3      Nintendo      E
# 4           NaN    NaN
# ...         ...    ...
# 16714       NaN    NaN
# 16715       NaN    NaN
# 16716       NaN    NaN
# 16717       NaN    NaN
# 16718       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
print(video_games_df['platform'].unique())
# Out:
# ['Wii' 'Nintendo' 'Game Boy' 'DS' 'Xbox 360' 'PlayStation 3'
#  'PlayStation 2' nan 'Game Boy Advance' 'PlayStation 4' '3DS'
#  'Nintendo 64' 'PlayStation' 'Xbox' 'PC' 'Atari' 'PlayStation Portable'
#  'Xbox One' 'Wii U' 'GameCube' 'Dreamcast' 'PlayStation Vita']

# %%
print(video_games_df['platform'].value_counts())
# Out:
# PlayStation 2           2161
# DS                      2152
# PlayStation 3           1331
# Wii                     1320
# Xbox 360                1262
# PlayStation Portable    1209
# PlayStation             1197
# PC                       974
# Xbox                     824
# Game Boy Advance         822
# GameCube                 556
# 3DS                      520
# PlayStation Vita         432
# PlayStation 4            393
# Nintendo 64              319
# Xbox One                 247
# Wii U                    147
# Atari                    133
# Nintendo                  98
# Game Boy                  98
# Dreamcast                 52
# Name: platform, dtype: int64

# %%
video_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16717 non-null  object
#  1   platform         16247 non-null  object
#  2   year_of_release  16450 non-null  float64
#  3   genre            16717 non-null  object
#  4   publisher        16665 non-null  object
#  5   na_sales         16719 non-null  float64
#  6   eu_sales         16719 non-null  float64
#  7   jp_sales         16719 non-null  float64
#  8   other_sales      16719 non-null  float64
#  9   global_sales     16719 non-null  float64
#  10  critic_score     8137 non-null   float64
#  11  critic_count     8137 non-null   float64
#  12  user_score       10015 non-null  object
#  13  user_count       7590 non-null   float64
#  14  developer        10096 non-null  object
#  15  rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
video_games_df.dropna(inplace=True)

# %%
video_games_df.isnull().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# publisher          0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# global_sales       0
# critic_score       0
# critic_count       0
# user_score         0
# user_count         0
# developer          0
# rating             0
# dtype: int64

# %%
# Check for duplicated rows
video_games_df.duplicated().sum()
# Out:
# 0

# %%
# Drop duplicated rows and verify removal
video_games_df.drop_duplicates()
video_games_df.duplicated().sum()
# Out:
# 0

# %%
video_games_df.dtypes
# Out:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# publisher           object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# global_sales       float64
# critic_score       float64
# critic_count       float64
# user_score          object
# user_count         float64
# developer           object
# rating              object
# dtype: object

# %%
# Change the year_of_release column to the int type and verify column types
video_games_df.loc[:, "year_of_release"] = video_games_df.loc[:, "year_of_release"].astype("int")
video_games_df.dtypes
# Out:
# name                object
# platform            object
# year_of_release      int32
# genre               object
# publisher           object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# global_sales       float64
# critic_score       float64
# critic_count       float64
# user_score          object
# user_count         float64
# developer           object
# rating              object
# dtype: object

# %%
video_games_df.describe()
# Out:
#        year_of_release     na_sales     eu_sales     jp_sales  other_sales  \
# count      6825.000000  6825.000000  6825.000000  6825.000000  6825.000000
# mean       2007.436777     0.394484     0.236089     0.064158     0.082677
# std           4.211248     0.967385     0.687330     0.287570     0.269871
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.390000     0.210000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        global_sales  critic_score  critic_count    user_count
# count   6825.000000   6825.000000   6825.000000   6825.000000
# mean       0.777590     70.272088     28.931136    174.722344
# std        1.963443     13.868572     19.224165    587.428538
# min        0.010000     13.000000      3.000000      4.000000
# 25%        0.110000     62.000000     14.000000     11.000000
# 50%        0.290000     72.000000     25.000000     27.000000
# 75%        0.750000     80.000000     39.000000     89.000000
# max       82.530000     98.000000    113.000000  10665.000000

# %%
video_games_df
# Out:
#                                     name          platform  year_of_release  \
# 0                             Wii Sports               Wii             2006
# 2                         Mario Kart Wii               Wii             2008
# 3                      Wii Sports Resort               Wii             2009
# 6                  New Super Mario Bros.                DS             2006
# 7                               Wii Play               Wii             2006
# ...                                  ...               ...              ...
# 16667         E.T. The Extra-Terrestrial  Game Boy Advance             2001
# 16677     Mortal Kombat: Deadly Alliance  Game Boy Advance             2002
# 16696  Metal Gear Solid V: Ground Zeroes                PC             2014
# 16700                             Breach                PC             2011
# 16706            STORM: Frontline Nation                PC             2011
#
#           genre                     publisher  na_sales  eu_sales  jp_sales  \
# 0        Sports                      Nintendo     41.36     28.96      3.77
# 2        Racing                      Nintendo     15.68     12.76      3.79
# 3        Sports                      Nintendo     15.61     10.93      3.28
# 6      Platform                      Nintendo     11.28      9.14      6.50
# 7          Misc                      Nintendo     13.96      9.18      2.93
# ...         ...                           ...       ...       ...       ...
# 16667    Action                      NewKidCo      0.01      0.00      0.00
# 16677  Fighting                  Midway Games      0.01      0.00      0.00
# 16696    Action  Konami Digital Entertainment      0.00      0.01      0.00
# 16700   Shooter                     Destineer      0.01      0.00      0.00
# 16706  Strategy                       Unknown      0.00      0.01      0.00
#
#        other_sales  global_sales  critic_score  critic_count user_score  \
# 0             8.45         82.53          76.0          51.0          8
# 2             3.29         35.52          82.0          73.0        8.3
# 3             2.95         32.77          80.0          73.0          8
# 6             2.88         29.80          89.0          65.0        8.5
# 7             2.84         28.92          58.0          41.0        6.6
# ...            ...           ...           ...           ...        ...
# 16667         0.00          0.01          46.0           4.0        2.4
# 16677         0.00          0.01          81.0          12.0        8.8
# 16696         0.00          0.01          80.0          20.0        7.6
# 16700         0.00          0.01          61.0          12.0        5.8
# 16706         0.00          0.01          60.0          12.0        7.2
#
#        user_count           developer rating
# 0           322.0            Nintendo      E
# 2           709.0            Nintendo      E
# 3           192.0            Nintendo      E
# 6           431.0            Nintendo      E
# 7           129.0            Nintendo      E
# ...           ...                 ...    ...
# 16667        21.0       Fluid Studios      E
# 16677         9.0     Criterion Games      M
# 16696       412.0  Kojima Productions      M
# 16700        43.0        Atomic Games      T
# 16706        13.0              SimBin   E10+
#
# [6825 rows x 16 columns]

# %%
#Creating new df for each table to simplify importation. 
details_df = video_games_df[['name', 'platform', 'year_of_release', 'genre', 'publisher', 'developer', 'rating']].copy()
details_df.head(10)
# Out:
#                          name  platform  year_of_release     genre  \
# 0                  Wii Sports       Wii             2006    Sports
# 2              Mario Kart Wii       Wii             2008    Racing
# 3           Wii Sports Resort       Wii             2009    Sports
# 6       New Super Mario Bros.        DS             2006  Platform
# 7                    Wii Play       Wii             2006      Misc
# 8   New Super Mario Bros. Wii       Wii             2009  Platform
# 11              Mario Kart DS        DS             2005    Racing
# 13                    Wii Fit       Wii             2007    Sports
# 14         Kinect Adventures!  Xbox 360             2010      Misc
# 15               Wii Fit Plus       Wii             2009    Sports
#
#                  publisher            developer rating
# 0                 Nintendo             Nintendo      E
# 2                 Nintendo             Nintendo      E
# 3                 Nintendo             Nintendo      E
# 6                 Nintendo             Nintendo      E
# 7                 Nintendo             Nintendo      E
# 8                 Nintendo             Nintendo      E
# 11                Nintendo             Nintendo      E
# 13                Nintendo             Nintendo      E
# 14  Microsoft Game Studios  Good Science Studio      E
# 15                Nintendo             Nintendo      E

# %%
reviews_df = video_games_df[['name', 'critic_score', 'critic_count', 'user_score', 'user_count']].copy()
reviews_df.head(10)
# Out:
#                          name  critic_score  critic_count user_score  \
# 0                  Wii Sports          76.0          51.0          8
# 2              Mario Kart Wii          82.0          73.0        8.3
# 3           Wii Sports Resort          80.0          73.0          8
# 6       New Super Mario Bros.          89.0          65.0        8.5
# 7                    Wii Play          58.0          41.0        6.6
# 8   New Super Mario Bros. Wii          87.0          80.0        8.4
# 11              Mario Kart DS          91.0          64.0        8.6
# 13                    Wii Fit          80.0          63.0        7.7
# 14         Kinect Adventures!          61.0          45.0        6.3
# 15               Wii Fit Plus          80.0          33.0        7.4
#
#     user_count
# 0        322.0
# 2        709.0
# 3        192.0
# 6        431.0
# 7        129.0
# 8        594.0
# 11       464.0
# 13       146.0
# 14       106.0
# 15        52.0

# %%
sales_df = video_games_df[['name', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'global_sales']].copy()
sales_df.head(100)
# Out:
#                       name  na_sales  eu_sales  jp_sales  other_sales  \
# 0               Wii Sports     41.36     28.96      3.77         8.45
# 2           Mario Kart Wii     15.68     12.76      3.79         3.29
# 3        Wii Sports Resort     15.61     10.93      3.28         2.95
# 6    New Super Mario Bros.     11.28      9.14      6.50         2.88
# 7                 Wii Play     13.96      9.18      2.93         2.84
# ..                     ...       ...       ...       ...          ...
# 139                 Driver      3.11      2.80      0.02         0.33
# 140         Gears of War 3      4.05      1.59      0.07         0.50
# 141          Kinect Sports      3.92      1.73      0.03         0.51
# 142           Gears of War      3.54      1.88      0.07         0.60
# 143                FIFA 15      0.80      4.33      0.05         0.90
#
#      global_sales
# 0           82.53
# 2           35.52
# 3           32.77
# 6           29.80
# 7           28.92
# ..            ...
# 139          6.27
# 140          6.21
# 141          6.19
# 142          6.09
# 143          6.08
#
# [100 rows x 6 columns]

# %%
video_games_df.to_csv('cleaned_video_games.csv')

# %%
#create details csv
details_df.to_csv('details.csv')

# %%
#create reviews csv
reviews_df.to_csv('reviews.csv')

# %%
#create sales csv
sales_df.to_csv('sales.csv')

# %%
video_games_df['na_sales_all_consoles'] = video_games_df.groupby('name')['na_sales'].transform('sum')

# %%
#for refference restating cleaned video game db
video_games_df.sort_values('name')

#groupby('name').agg({'year_of_release':min, }) sum/min/max/mean
# Out:
#                                name              platform  year_of_release  \
# 2454              Tales of Xillia 2         PlayStation 3             2012
# 1561        .hack//Infection Part 1         PlayStation 2             2002
# 2990         .hack//Mutation Part 2         PlayStation 2             2002
# 4265         .hack//Outbreak Part 3         PlayStation 2             2002
# 3757                     007 Racing           PlayStation             2000
# ...                             ...                   ...              ...
# 3304      pro evolution soccer 2011              Xbox 360             2010
# 2583      pro evolution soccer 2011  PlayStation Portable             2010
# 649       pro evolution soccer 2011         PlayStation 3             2010
# 7150      pro evolution soccer 2011                   Wii             2010
# 15614  uDraw Studio: Instant Artist              Xbox 360             2011
#
#               genre                     publisher  na_sales  eu_sales  \
# 2454   Role-Playing            Namco Bandai Games      0.20      0.12
# 1561   Role-Playing                         Atari      0.49      0.38
# 2990   Role-Playing                         Atari      0.23      0.18
# 4265   Role-Playing                         Atari      0.14      0.11
# 3757         Racing               Electronic Arts      0.30      0.20
# ...             ...                           ...       ...       ...
# 3304         Sports  Konami Digital Entertainment      0.09      0.44
# 2583         Sports  Konami Digital Entertainment      0.05      0.30
# 649          Sports  Konami Digital Entertainment      0.29      1.17
# 7150         Sports  Konami Digital Entertainment      0.07      0.10
# 15614          Misc                           THQ      0.01      0.01
#
#        jp_sales  other_sales  global_sales  critic_score  critic_count  \
# 2454       0.45         0.07          0.84          71.0          59.0
# 1561       0.26         0.13          1.27          75.0          35.0
# 2990       0.20         0.06          0.68          76.0          24.0
# 4265       0.17         0.04          0.46          70.0          23.0
# 3757       0.00         0.03          0.53          51.0          16.0
# ...         ...          ...           ...           ...           ...
# 3304       0.00         0.07          0.61          79.0          43.0
# 2583       0.29         0.16          0.79          74.0          10.0
# 649        0.54         0.41          2.41          77.0          40.0
# 7150       0.03         0.02          0.22          78.0           9.0
# 15614      0.00         0.00          0.02          54.0           5.0
#
#       user_score  user_count           developer rating  na_sales_all_consoles
# 2454         7.9       216.0  Bandai Namco Games      T                   0.20
# 1561         8.5        60.0       CyberConnect2      T                   0.49
# 2990         8.9        81.0       CyberConnect2      T                   0.23
# 4265         8.7        19.0       CyberConnect2      T                   0.14
# 3757         4.6        14.0           Eutechnyx      T                   0.30
# ...          ...         ...                 ...    ...                    ...
# 3304         5.9        33.0              Konami      E                   0.50
# 2583         5.8         5.0              Konami      E                   0.50
# 649          6.8        85.0              Konami      E                   0.50
# 7150         5.4         7.0              Konami      E                   0.50
# 15614        5.7         6.0                 THQ      E                   0.01
#
# [6825 rows x 17 columns]

# %%
group_features = ['name', 'year_of_release', 'genre', 'publisher', 'developer','rating', 'global_sales', 'critic_score', 'critic_count', 'user_score', 'user_count']
for feature in group_features:
    print(feature)
    print(video_games_df.groupby('name')[feature].nunique().value_counts(ascending=False))
    print(" ")
# Out:
# name
# 1    4377
# Name: name, dtype: int64
#
# year_of_release
# 1    4168
# 2     200
# 3       7
# 4       2
# Name: year_of_release, dtype: int64
#
# genre
# 1    4377
# Name: genre, dtype: int64
#
# publisher
# 1    4283
# 2      90
# 3       3
# 4       1
# Name: publisher, dtype: int64
#
# developer
# 1    3998
# 2     323
# 3      43
# 4      11
# 5       2
# Name: developer, dtype: int64
#
# rating
# 1    4280
# 2      94
# 3       3
# Name: rating, dtype: int64
#
# global_sales
# 1    2985
# 2     744
# 3     436
# 4     119
# 5      60
# 6      23
# 7       7
# 8       3
# Name: global_sales, dtype: int64
#
# critic_score
# 1    3077
# 2     814
# 3     326
# 4     108
# 5      41
# 6       6
# 7       4
# 8       1
# Name: critic_score, dtype: int64
#
# critic_count
# 1    3005
# 2     731
# 3     434
# 4     124
# 5      57
# 6      18
# 7       6
# 8       2
# Name: critic_count, dtype: int64
#
# user_score
# 1    2998
# 2     783
# 3     409
# 4     112
# 5      53
# 6      18
# 7       3
# 8       1
# Name: user_score, dtype: int64
#
# user_count
# 1    2983
# 2     744
# 3     445
# 4     117
# 5      58
# 6      23
# 7       5
# 8       2
# Name: user_count, dtype: int64

# %%
aggregate_video_games_df = video_games_df.groupby(['name', 'year_of_release', 'genre', 'publisher', 'developer', 
                                                   'rating', 'global_sales', 'critic_score', 'critic_count', 'user_score', 'user_count']
                                                 )['na_sales', 'eu_sales', 'jp_sales','other_sales'].sum().reset_index()
aggregate_video_games_df
# Out:
# C:\Users\jorda\AppData\Local\Temp\ipykernel_23284\2606631358.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   aggregate_video_games_df = video_games_df.groupby(['name', 'year_of_release', 'genre', 'publisher', 'developer', 'rating', 'global_sales', 'critic_score', 'critic_count', 'user_score', 'user_count'])['na_sales', 'eu_sales', 'jp_sales','other_sales'].sum().reset_index()
#                               name  year_of_release         genre  \
# 0                Tales of Xillia 2             2012  Role-Playing
# 1          .hack//Infection Part 1             2002  Role-Playing
# 2           .hack//Mutation Part 2             2002  Role-Playing
# 3           .hack//Outbreak Part 3             2002  Role-Playing
# 4                       007 Racing             2000        Racing
# ...                            ...              ...           ...
# 6820     pro evolution soccer 2011             2010        Sports
# 6821     pro evolution soccer 2011             2010        Sports
# 6822     pro evolution soccer 2011             2010        Sports
# 6823     pro evolution soccer 2011             2010        Sports
# 6824  uDraw Studio: Instant Artist             2011          Misc
#
#                          publisher           developer rating  global_sales  \
# 0               Namco Bandai Games  Bandai Namco Games      T          0.84
# 1                            Atari       CyberConnect2      T          1.27
# 2                            Atari       CyberConnect2      T          0.68
# 3                            Atari       CyberConnect2      T          0.46
# 4                  Electronic Arts           Eutechnyx      T          0.53
# ...                            ...                 ...    ...           ...
# 6820  Konami Digital Entertainment              Konami      E          0.22
# 6821  Konami Digital Entertainment              Konami      E          0.61
# 6822  Konami Digital Entertainment              Konami      E          0.79
# 6823  Konami Digital Entertainment              Konami      E          2.41
# 6824                           THQ                 THQ      E          0.02
#
#       critic_score  critic_count user_score  user_count  na_sales  eu_sales  \
# 0             71.0          59.0        7.9       216.0      0.20      0.12
# 1             75.0          35.0        8.5        60.0      0.49      0.38
# 2             76.0          24.0        8.9        81.0      0.23      0.18
# 3             70.0          23.0        8.7        19.0      0.14      0.11
# 4             51.0          16.0        4.6        14.0      0.30      0.20
# ...            ...           ...        ...         ...       ...       ...
# 6820          78.0           9.0        5.4         7.0      0.07      0.10
# 6821          79.0          43.0        5.9        33.0      0.09      0.44
# 6822          74.0          10.0        5.8         5.0      0.05      0.30
# 6823          77.0          40.0        6.8        85.0      0.29      1.17
# 6824          54.0           5.0        5.7         6.0      0.01      0.01
#
#       jp_sales  other_sales
# 0         0.45         0.07
# 1         0.26         0.13
# 2         0.20         0.06
# 3         0.17         0.04
# 4         0.00         0.03
# ...        ...          ...
# 6820      0.03         0.02
# 6821      0.00         0.07
# 6822      0.29         0.16
# 6823      0.54         0.41
# 6824      0.00         0.00
#
# [6825 rows x 15 columns]

# %%
duplicates = video_games_df.duplicated(subset=['name'])

# Print the duplicates
print(duplicates)
# Out:
# 0        False
# 2        False
# 3        False
# 6        False
# 7        False
#          ...
# 16667    False
# 16677     True
# 16696     True
# 16700    False
# 16706    False
# Length: 6825, dtype: bool
