# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# File to Load (Remember to change these)
video_games_to_load = "Data/video_games.csv"

# Read the all games and video games Data
video_games_df = pd.read_csv(video_games_to_load)

# %%
video_games_df.head(10)
# Out:
#    Unnamed: 0                       name  platform  year_of_release     genre  \
# 0           0                 Wii Sports       Wii             2006    Sports
# 1           2             Mario Kart Wii       Wii             2008    Racing
# 2           3          Wii Sports Resort       Wii             2009    Sports
# 3           7      New Super Mario Bros.        DS             2006  Platform
# 4           8                   Wii Play       Wii             2006      Misc
# 5           9  New Super Mario Bros. Wii       Wii             2009  Platform
# 6          12              Mario Kart DS        DS             2005    Racing
# 7          14                    Wii Fit       Wii             2007    Sports
# 8          15         Kinect Adventures!  Xbox 360             2010      Misc
# 9          16               Wii Fit Plus       Wii             2009    Sports
#
#                 publisher  na_sales  eu_sales  jp_sales  other_sales  ...  \
# 0                Nintendo     41.36     28.96      3.77         8.45  ...
# 1                Nintendo     15.68     12.76      3.79         3.29  ...
# 2                Nintendo     15.61     10.93      3.28         2.95  ...
# 3                Nintendo     11.28      9.14      6.50         2.88  ...
# 4                Nintendo     13.96      9.18      2.93         2.84  ...
# 5                Nintendo     14.44      6.94      4.70         2.24  ...
# 6                Nintendo      9.71      7.47      4.13         1.90  ...
# 7                Nintendo      8.92      8.03      3.60         2.15  ...
# 8  Microsoft Game Studios     15.00      4.89      0.24         1.69  ...
# 9                Nintendo      9.01      8.49      2.53         1.77  ...
#
#    critic_count  user_score  user_count            developer  rating  \
# 0          51.0         8.0       322.0             Nintendo       E
# 1          73.0         8.3       709.0             Nintendo       E
# 2          73.0         8.0       192.0             Nintendo       E
# 3          65.0         8.5       431.0             Nintendo       E
# 4          41.0         6.6       129.0             Nintendo       E
# 5          80.0         8.4       594.0             Nintendo       E
# 6          64.0         8.6       464.0             Nintendo       E
# 7          63.0         7.7       146.0             Nintendo       E
# 8          45.0         6.3       106.0  Good Science Studio       E
# 9          33.0         7.4        52.0             Nintendo       E
#
#   platform_y release_date                                            summary  \
# 0        Wii   2006-11-19  Tennis (1-4 players): Players grab the control...
# 1        Wii   2008-04-27  Mario Kart Wii comes with the intuitive Wii Wh...
# 2        Wii   2009-07-26  Wii Sports Resort is a collection of fun sport...
# 3         DS   2006-05-15  The first new 2D Mario platformer since Super ...
# 4        Wii   2007-02-12  In Wii Play  the star of the game is you. Crea...
# 5        Wii   2009-11-15  New Super Mario Bros. Wii offers a combination...
# 6         DS   2005-11-14  Race and battle with up to eight karts at once...
# 7        Wii   2008-05-19  The active-play phenomenon started by Wii Spor...
# 8   Xbox 360   2010-11-04  Kinect Adventures is a compilation of games fo...
# 9        Wii   2009-10-04  Wii Fit Plus is the new  enhanced version of t...
#
#   meta_score user_review
# 0       76.0         8.1
# 1       82.0         8.4
# 2       80.0         8.2
# 3       89.0         8.5
# 4       58.0         6.6
# 5       87.0         8.3
# 6       91.0         8.7
# 7       80.0         7.7
# 8       61.0         6.3
# 9       80.0         7.5
#
# [10 rows x 22 columns]

# %%
video_games_df.shape
# Out:
# (14396, 22)

# %%
video_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14396 entries, 0 to 14395
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       14396 non-null  int64
#  1   name             14396 non-null  object
#  2   platform         14396 non-null  object
#  3   year_of_release  14396 non-null  int64
#  4   genre            14396 non-null  object
#  5   publisher        14396 non-null  object
#  6   na_sales         14396 non-null  float64
#  7   eu_sales         14396 non-null  float64
#  8   jp_sales         14396 non-null  float64
#  9   other_sales      14396 non-null  float64
#  10  global_sales     14396 non-null  float64
#  11  critic_score     14396 non-null  float64
#  12  critic_count     14396 non-null  float64
#  13  user_score       14396 non-null  float64
#  14  user_count       14396 non-null  float64
#  15  developer        14396 non-null  object
#  16  rating           14396 non-null  object
#  17  platform_y       14396 non-null  object
#  18  release_date     14396 non-null  object
#  19  summary          14396 non-null  object
#  20  meta_score       14396 non-null  float64
#  21  user_review      14396 non-null  object
# dtypes: float64(10), int64(2), object(10)
# memory usage: 2.4+ MB

# %%
# Rename Name to name column in video_games_df
video_games_df.columns = video_games_df.columns.str.lower()
video_games_df
# Out:
#        unnamed: 0                               name          platform  \
# 0               0                         Wii Sports               Wii
# 1               2                     Mario Kart Wii               Wii
# 2               3                  Wii Sports Resort               Wii
# 3               7              New Super Mario Bros.                DS
# 4               8                           Wii Play               Wii
# ...           ...                                ...               ...
# 14391       27207     Mortal Kombat: Deadly Alliance  Game Boy Advance
# 14392       27226  Metal Gear Solid V: Ground Zeroes                PC
# 14393       27227  Metal Gear Solid V: Ground Zeroes                PC
# 14394       27228  Metal Gear Solid V: Ground Zeroes                PC
# 14395       27232                             Breach                PC
#
#        year_of_release     genre                     publisher  na_sales  \
# 0                 2006    Sports                      Nintendo     41.36
# 1                 2008    Racing                      Nintendo     15.68
# 2                 2009    Sports                      Nintendo     15.61
# 3                 2006  Platform                      Nintendo     11.28
# 4                 2006      Misc                      Nintendo     13.96
# ...                ...       ...                           ...       ...
# 14391             2002  Fighting                  Midway Games      0.01
# 14392             2014    Action  Konami Digital Entertainment      0.00
# 14393             2014    Action  Konami Digital Entertainment      0.00
# 14394             2014    Action  Konami Digital Entertainment      0.00
# 14395             2011   Shooter                     Destineer      0.01
#
#        eu_sales  jp_sales  other_sales  ...  critic_count  user_score  \
# 0         28.96      3.77         8.45  ...          51.0         8.0
# 1         12.76      3.79         3.29  ...          73.0         8.3
# 2         10.93      3.28         2.95  ...          73.0         8.0
# 3          9.14      6.50         2.88  ...          65.0         8.5
# 4          9.18      2.93         2.84  ...          41.0         6.6
# ...         ...       ...          ...  ...           ...         ...
# 14391      0.00      0.00         0.00  ...          12.0         8.8
# 14392      0.01      0.00         0.00  ...          20.0         7.6
# 14393      0.01      0.00         0.00  ...          20.0         7.6
# 14394      0.01      0.00         0.00  ...          20.0         7.6
# 14395      0.00      0.00         0.00  ...          12.0         5.8
#
#        user_count           developer  rating      platform_y release_date  \
# 0           322.0            Nintendo       E             Wii   2006-11-19
# 1           709.0            Nintendo       E             Wii   2008-04-27
# 2           192.0            Nintendo       E             Wii   2009-07-26
# 3           431.0            Nintendo       E              DS   2006-05-15
# 4           129.0            Nintendo       E             Wii   2007-02-12
# ...           ...                 ...     ...             ...          ...
# 14391         9.0     Criterion Games       M   PlayStation 2   2002-11-16
# 14392       412.0  Kojima Productions       M              PC   2014-12-18
# 14393       412.0  Kojima Productions       M        Xbox One   2014-03-18
# 14394       412.0  Kojima Productions       M   PlayStation 4   2014-03-18
# 14395        43.0        Atomic Games       T        Xbox 360   2011-01-26
#
#                                                  summary meta_score  \
# 0      Tennis (1-4 players): Players grab the control...       76.0
# 1      Mario Kart Wii comes with the intuitive Wii Wh...       82.0
# 2      Wii Sports Resort is a collection of fun sport...       80.0
# 3      The first new 2D Mario platformer since Super ...       89.0
# 4      In Wii Play  the star of the game is you. Crea...       58.0
# ...                                                  ...        ...
# 14391  Deadly Alliance features a completely new figh...       79.0
# 14392  Metal Gear Solid V: Ground Zeroes is the first...       80.0
# 14393  Ground Zeroes showcases Kojima Productions' FO...       76.0
# 14394  Ground Zeroes showcases Kojima Productions' FO...       75.0
# 14395  Breach is a multiplayer first-person shooter b...       57.0
#
#       user_review
# 0             8.1
# 1             8.4
# 2             8.2
# 3             8.5
# 4             6.6
# ...           ...
# 14391         8.4
# 14392         7.6
# 14393         5.6
# 14394         6.4
# 14395         4.4
#
# [14396 rows x 22 columns]

# %%
# renaming platform types abrv in video_games_df to match all_games_df platform names using the mapping method
mapping = {'N64':'Nintendo 64','PS':'PlayStation','PS3': 'PlayStation 3','DC':'Dreamcast','X360':'Xbox 360','XOne':'Xbox One',
          'Wii':'Wii','PC':'PC','PS2':'PlayStation 2','PS4':'PlayStation 4','GC':'GameCube','XB':'Xbox','WiiU':'Wii U',
          'GBA':'Game Boy Advance','3DS':'3DS','2600':'Atari','DS':'DS','PSV':'PlayStation Vita','PSP':'PSP','GB':'Game Boy',
           'NES':'Nintendo','PSP':'PlayStation Portable'}
video_games_df['platform'] = video_games_df['platform'].map(mapping)
video_games_df
# Out:
#        unnamed: 0                               name platform  \
# 0               0                         Wii Sports      Wii
# 1               2                     Mario Kart Wii      Wii
# 2               3                  Wii Sports Resort      Wii
# 3               7              New Super Mario Bros.       DS
# 4               8                           Wii Play      Wii
# ...           ...                                ...      ...
# 14391       27207     Mortal Kombat: Deadly Alliance      NaN
# 14392       27226  Metal Gear Solid V: Ground Zeroes       PC
# 14393       27227  Metal Gear Solid V: Ground Zeroes       PC
# 14394       27228  Metal Gear Solid V: Ground Zeroes       PC
# 14395       27232                             Breach       PC
#
#        year_of_release     genre                     publisher  na_sales  \
# 0                 2006    Sports                      Nintendo     41.36
# 1                 2008    Racing                      Nintendo     15.68
# 2                 2009    Sports                      Nintendo     15.61
# 3                 2006  Platform                      Nintendo     11.28
# 4                 2006      Misc                      Nintendo     13.96
# ...                ...       ...                           ...       ...
# 14391             2002  Fighting                  Midway Games      0.01
# 14392             2014    Action  Konami Digital Entertainment      0.00
# 14393             2014    Action  Konami Digital Entertainment      0.00
# 14394             2014    Action  Konami Digital Entertainment      0.00
# 14395             2011   Shooter                     Destineer      0.01
#
#        eu_sales  jp_sales  other_sales  ...  critic_count  user_score  \
# 0         28.96      3.77         8.45  ...          51.0         8.0
# 1         12.76      3.79         3.29  ...          73.0         8.3
# 2         10.93      3.28         2.95  ...          73.0         8.0
# 3          9.14      6.50         2.88  ...          65.0         8.5
# 4          9.18      2.93         2.84  ...          41.0         6.6
# ...         ...       ...          ...  ...           ...         ...
# 14391      0.00      0.00         0.00  ...          12.0         8.8
# 14392      0.01      0.00         0.00  ...          20.0         7.6
# 14393      0.01      0.00         0.00  ...          20.0         7.6
# 14394      0.01      0.00         0.00  ...          20.0         7.6
# 14395      0.00      0.00         0.00  ...          12.0         5.8
#
#        user_count           developer  rating      platform_y release_date  \
# 0           322.0            Nintendo       E             Wii   2006-11-19
# 1           709.0            Nintendo       E             Wii   2008-04-27
# 2           192.0            Nintendo       E             Wii   2009-07-26
# 3           431.0            Nintendo       E              DS   2006-05-15
# 4           129.0            Nintendo       E             Wii   2007-02-12
# ...           ...                 ...     ...             ...          ...
# 14391         9.0     Criterion Games       M   PlayStation 2   2002-11-16
# 14392       412.0  Kojima Productions       M              PC   2014-12-18
# 14393       412.0  Kojima Productions       M        Xbox One   2014-03-18
# 14394       412.0  Kojima Productions       M   PlayStation 4   2014-03-18
# 14395        43.0        Atomic Games       T        Xbox 360   2011-01-26
#
#                                                  summary meta_score  \
# 0      Tennis (1-4 players): Players grab the control...       76.0
# 1      Mario Kart Wii comes with the intuitive Wii Wh...       82.0
# 2      Wii Sports Resort is a collection of fun sport...       80.0
# 3      The first new 2D Mario platformer since Super ...       89.0
# 4      In Wii Play  the star of the game is you. Crea...       58.0
# ...                                                  ...        ...
# 14391  Deadly Alliance features a completely new figh...       79.0
# 14392  Metal Gear Solid V: Ground Zeroes is the first...       80.0
# 14393  Ground Zeroes showcases Kojima Productions' FO...       76.0
# 14394  Ground Zeroes showcases Kojima Productions' FO...       75.0
# 14395  Breach is a multiplayer first-person shooter b...       57.0
#
#       user_review
# 0             8.1
# 1             8.4
# 2             8.2
# 3             8.5
# 4             6.6
# ...           ...
# 14391         8.4
# 14392         7.6
# 14393         5.6
# 14394         6.4
# 14395         4.4
#
# [14396 rows x 22 columns]

# %%
print(video_games_df['platform'].unique())
# Out:
# ['Wii' 'DS' nan '3DS' 'PC']

# %%
print(video_games_df['platform'].value_counts())
# Out:
# PC     1418
# Wii     928
# DS      792
# 3DS     239
# Name: platform, dtype: int64

# %%
video_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14396 entries, 0 to 14395
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   unnamed: 0       14396 non-null  int64
#  1   name             14396 non-null  object
#  2   platform         3377 non-null   object
#  3   year_of_release  14396 non-null  int64
#  4   genre            14396 non-null  object
#  5   publisher        14396 non-null  object
#  6   na_sales         14396 non-null  float64
#  7   eu_sales         14396 non-null  float64
#  8   jp_sales         14396 non-null  float64
#  9   other_sales      14396 non-null  float64
#  10  global_sales     14396 non-null  float64
#  11  critic_score     14396 non-null  float64
#  12  critic_count     14396 non-null  float64
#  13  user_score       14396 non-null  float64
#  14  user_count       14396 non-null  float64
#  15  developer        14396 non-null  object
#  16  rating           14396 non-null  object
#  17  platform_y       14396 non-null  object
#  18  release_date     14396 non-null  object
#  19  summary          14396 non-null  object
#  20  meta_score       14396 non-null  float64
#  21  user_review      14396 non-null  object
# dtypes: float64(10), int64(2), object(10)
# memory usage: 2.4+ MB

# %%
video_games_df.dropna(inplace=True)

# %%
video_games_df.isnull().sum()
# Out:
# unnamed: 0         0
# name               0
# platform           0
# year_of_release    0
# genre              0
# publisher          0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# global_sales       0
# critic_score       0
# critic_count       0
# user_score         0
# user_count         0
# developer          0
# rating             0
# platform_y         0
# release_date       0
# summary            0
# meta_score         0
# user_review        0
# dtype: int64

# %%
# Check for duplicated rows
video_games_df.duplicated().sum(0)
# Out:
# 0

# %%
# Drop duplicated rows and verify removal
video_games_df.drop_duplicates()
video_games_df.duplicated().sum(0)
# Out:
# 0

# %%
video_games_df.dtypes
# Out:
# unnamed: 0           int64
# name                object
# platform            object
# year_of_release      int64
# genre               object
# publisher           object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# global_sales       float64
# critic_score       float64
# critic_count       float64
# user_score         float64
# user_count         float64
# developer           object
# rating              object
# platform_y          object
# release_date        object
# summary             object
# meta_score         float64
# user_review         object
# dtype: object

# %%
# Change the year_of_release column to the int type and verify column types
video_games_df.loc[:, "year_of_release"] = video_games_df.loc[:, "year_of_release"].astype("int")
video_games_df.dtypes
# Out:
# unnamed: 0           int64
# name                object
# platform            object
# year_of_release      int32
# genre               object
# publisher           object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# global_sales       float64
# critic_score       float64
# critic_count       float64
# user_score         float64
# user_count         float64
# developer           object
# rating              object
# platform_y          object
# release_date        object
# summary             object
# meta_score         float64
# user_review         object
# dtype: object

# %%
video_games_df.describe()
# Out:
#          unnamed: 0  year_of_release     na_sales     eu_sales     jp_sales  \
# count   3377.000000      3377.000000  3377.000000  3377.000000  3377.000000
# mean   14518.447142      2008.909683     0.293394     0.212727     0.048345
# std     8042.790336         3.100100     1.059240     0.799836     0.315960
# min        0.000000      1988.000000     0.000000     0.000000     0.000000
# 25%     7645.000000      2007.000000     0.010000     0.010000     0.000000
# 50%    14814.000000      2009.000000     0.100000     0.040000     0.000000
# 75%    22164.000000      2011.000000     0.280000     0.170000     0.000000
# max    27232.000000      2016.000000    41.360000    28.960000     6.500000
#
#        other_sales  global_sales  critic_score  critic_count   user_score  \
# count  3377.000000   3377.000000   3377.000000   3377.000000  3377.000000
# mean      0.054084      0.608857     70.587504     23.871780     6.930086
# std       0.211791      2.226468     13.308235     16.386272     1.456580
# min       0.000000      0.010000     19.000000      4.000000     0.700000
# 25%       0.010000      0.060000     63.000000     11.000000     6.100000
# 50%       0.020000      0.190000     73.000000     19.000000     7.300000
# 75%       0.050000      0.530000     80.000000     32.000000     8.000000
# max       8.450000     82.530000     97.000000    104.000000     9.300000
#
#          user_count   meta_score
# count   3377.000000  3377.000000
# mean     353.693515    71.503998
# std      979.279488    12.837115
# min        4.000000    23.000000
# 25%       13.000000    64.000000
# 50%       34.000000    73.000000
# 75%      235.000000    81.000000
# max    10665.000000    98.000000

# %%
video_games_df
# Out:
#        unnamed: 0                               name platform  \
# 0               0                         Wii Sports      Wii
# 1               2                     Mario Kart Wii      Wii
# 2               3                  Wii Sports Resort      Wii
# 3               7              New Super Mario Bros.       DS
# 4               8                           Wii Play      Wii
# ...           ...                                ...      ...
# 14387       27170                    Hospital Tycoon       PC
# 14392       27226  Metal Gear Solid V: Ground Zeroes       PC
# 14393       27227  Metal Gear Solid V: Ground Zeroes       PC
# 14394       27228  Metal Gear Solid V: Ground Zeroes       PC
# 14395       27232                             Breach       PC
#
#        year_of_release     genre                     publisher  na_sales  \
# 0                 2006    Sports                      Nintendo     41.36
# 1                 2008    Racing                      Nintendo     15.68
# 2                 2009    Sports                      Nintendo     15.61
# 3                 2006  Platform                      Nintendo     11.28
# 4                 2006      Misc                      Nintendo     13.96
# ...                ...       ...                           ...       ...
# 14387             2007  Strategy                   Codemasters      0.00
# 14392             2014    Action  Konami Digital Entertainment      0.00
# 14393             2014    Action  Konami Digital Entertainment      0.00
# 14394             2014    Action  Konami Digital Entertainment      0.00
# 14395             2011   Shooter                     Destineer      0.01
#
#        eu_sales  jp_sales  other_sales  ...  critic_count  user_score  \
# 0         28.96      3.77         8.45  ...          51.0         8.0
# 1         12.76      3.79         3.29  ...          73.0         8.3
# 2         10.93      3.28         2.95  ...          73.0         8.0
# 3          9.14      6.50         2.88  ...          65.0         8.5
# 4          9.18      2.93         2.84  ...          41.0         6.6
# ...         ...       ...          ...  ...           ...         ...
# 14387      0.01      0.00         0.00  ...           8.0         3.8
# 14392      0.01      0.00         0.00  ...          20.0         7.6
# 14393      0.01      0.00         0.00  ...          20.0         7.6
# 14394      0.01      0.00         0.00  ...          20.0         7.6
# 14395      0.00      0.00         0.00  ...          12.0         5.8
#
#        user_count           developer  rating      platform_y release_date  \
# 0           322.0            Nintendo       E             Wii   2006-11-19
# 1           709.0            Nintendo       E             Wii   2008-04-27
# 2           192.0            Nintendo       E             Wii   2009-07-26
# 3           431.0            Nintendo       E              DS   2006-05-15
# 4           129.0            Nintendo       E             Wii   2007-02-12
# ...           ...                 ...     ...             ...          ...
# 14387        29.0    Big Red Software    E10+            Xbox   2007-06-05
# 14392       412.0  Kojima Productions       M              PC   2014-12-18
# 14393       412.0  Kojima Productions       M        Xbox One   2014-03-18
# 14394       412.0  Kojima Productions       M   PlayStation 4   2014-03-18
# 14395        43.0        Atomic Games       T        Xbox 360   2011-01-26
#
#                                                  summary meta_score  \
# 0      Tennis (1-4 players): Players grab the control...       76.0
# 1      Mario Kart Wii comes with the intuitive Wii Wh...       82.0
# 2      Wii Sports Resort is a collection of fun sport...       80.0
# 3      The first new 2D Mario platformer since Super ...       89.0
# 4      In Wii Play  the star of the game is you. Crea...       58.0
# ...                                                  ...        ...
# 14387  At the Sapphire Beach Medical Institute  the l...       51.0
# 14392  Metal Gear Solid V: Ground Zeroes is the first...       80.0
# 14393  Ground Zeroes showcases Kojima Productions' FO...       76.0
# 14394  Ground Zeroes showcases Kojima Productions' FO...       75.0
# 14395  Breach is a multiplayer first-person shooter b...       57.0
#
#       user_review
# 0             8.1
# 1             8.4
# 2             8.2
# 3             8.5
# 4             6.6
# ...           ...
# 14387         4.0
# 14392         7.6
# 14393         5.6
# 14394         6.4
# 14395         4.4
#
# [3377 rows x 22 columns]

# %%
video_games_df['summary'] = merged_video_games_df['summary'].str.replace(',', ' ')
video_games_df['release_date'] = pd.to_datetime(merged_video_games_df['release_date'])
video_games_df

# %%
merged_video_games_df = merged_video_games_df.rename(columns={'platform_x': 'platform'})
merged_video_games_df

# %%
merged_video_games_df.dtypes

# %%
#Creating new df for each table to simplify importation. 
details_df = merged_video_games_df[['name', 'platform', 'year_of_release', 'genre', 'publisher', 'developer', 'rating']].copy()
details_df.head(10)

# %%
reviews_df = merged_video_games_df[['name', 'critic_score', 'critic_count', 'user_score', 'user_count']].copy()
reviews_df.head(10)

# %%
sales_df = merged_video_games_df[['name', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'global_sales']].copy()
sales_df.head(10)

# %%
# check for duplicates
duplicates = details_df.duplicated()

# print the rows that are duplicates
print(details_df[duplicates])

#How to handle duplicates?
details_df.to_csv('details.csv')

# %%
# check for duplicates
duplicates = reviews_df.duplicated()

# print the rows that are duplicates
print(reviews_df[duplicates])

#How to handle duplicates?
reviews_df.to_csv('reviews.csv')

# %%
# check for duplicates
duplicates = sales_df.duplicated()

# print the rows that are duplicates
print(sales_df[duplicates])

#How to handle duplicates?
sales_df.to_csv('sales.csv')

# %%
merged_video_games_df.to_csv('merged_video_games.csv')
